# %%
import pandas as pd

# %%
data = pd.read_csv( r"hrdata.csv" )
print( f"data.shape = { data.shape }" )
data.head()
# Out:
# data.shape = (1470, 24)
#    EmployeeCount  EmployeeID              Department                JobRole  \
# 0              1           1                   Sales        Sales Executive
# 1              1           2  Research & Development     Research Scientist
# 2              1           4  Research & Development  Laboratory Technician
# 3              1           5  Research & Development     Research Scientist
# 4              1           7  Research & Development  Laboratory Technician
#
#   Attrition  Gender  Age MaritalStatus      Education EducationField  ...  \
# 0       Yes  Female   41        Single        College  Life Sciences  ...
# 1        No    Male   49       Married  Below College  Life Sciences  ...
# 2       Yes    Male   37        Single        College          Other  ...
# 3        No  Female   33       Married         Master  Life Sciences  ...
# 4        No    Male   27       Married  Below College        Medical  ...
#
# ...

# %%
# x : label or position, default None
# Only used if data is a DataFrame.

data.plot( x = 'Income' )

# %%
# y : label, position or list of label, positions, default None
# Allows plotting of one column versus another. Only used if data is a DataFrame.

data.plot( y = 'Income' )

# %%
data.plot( x = 'Income', y = 'Age' )

# %%
# kind : str
# The kind of plot to produce: 
# ‘line’ : line plot (default)

data.plot( x = 'Income', y = 'Age', kind = 'line' )

# %%
# ‘bar’ : vertical bar plot

data.plot( x = 'Income', y = 'Age', kind = 'bar' )

# %%
# ‘barh’ : horizontal bar plot

data.plot( x = 'Income', y = 'Age', kind = 'barh' )

# %%
#‘hist’ : histogram

data.plot( x = 'Income', y = 'Age', kind = 'hist' )

# %%
# ‘box’ : boxplot

data.plot( x = 'Income', kind = 'box' )

# %%
# ‘box’ : boxplot

data.plot( y = 'Age', kind = 'box' )

# %%
# ‘box’ : boxplot

data.plot( x = 'Income', y = 'Age', kind = 'box' )

# %%
# ‘kde’ : Kernel Density Estimation plot

data.plot( x = 'Income', y = 'Age', kind = 'kde' )

# %%
# ‘density’ : same as ‘kde’

data.plot( x = 'Income', y = 'Age', kind = 'density' )

# %%
# ‘area’ : area plot

data.plot( x = 'Income', y = 'Age', kind = 'area' )

# %%
# ‘pie’ : pie plot

data.plot( x = 'Income', y = 'Age', kind = 'pie' )

# %%
# ‘scatter’ : scatter plot

data.plot( x = 'Income', y = 'Age', kind = 'scatter' )

# %%
# ‘hexbin’ : hexbin plot.

data.plot( x = 'Income', y = 'Age', kind = 'hexbin' )

# %%
# figsize : a tuple (width, height) in inches
# use_index : bool, default True
# Use index as ticks for x axis.

data.plot( x = 'Income', y = 'Age', kind = 'scatter', figsize = (10, 10) )

# %%
# title : str or list
# Title to use for the plot. If a string is passed, print the string at the top of the figure. 
# If a list is passed and subplots is True, print each item in the list above the corresponding subplot.

data.plot( x = 'Income'
          , y = 'Age'
          , kind = 'scatter'
          , figsize = (10, 10)
          , title = 'Pandas_Graphs' )

# %%
# grid : bool, default None (matlab style default)
# Axis grid lines.

data.plot( x = 'Income'
          , y = 'Age'
          , kind = 'scatter'
          , figsize = (10, 10)
          , title = 'Pandas_Graphs'
          , grid = None )

# %%
data.plot( x = 'Income'
          , y = 'Age'
          , kind = 'scatter'
          , figsize = (10, 10)
          , title = 'Pandas_Graphs'
          , grid = False )

# %%
data.plot( x = 'Income'
          , y = 'Age'
          , kind = 'scatter'
          , figsize = (10, 10)
          , title = 'Pandas_Graphs'
          , grid = True )

# %%
# logx : bool or ‘sym’, default False
# Use log scaling or symlog scaling on x axis. .. versionchanged:: 0.25.0

data.plot( x = 'Income'
          , y = 'Age'
          , kind = 'scatter'
          , figsize = (10, 10)
          , title = 'Pandas_Graphs'
          , grid = True
          , logx = 'sym' )

# %%
# logy : bool or ‘sym’ default False
# Use log scaling or symlog scaling on y axis. .. versionchanged:: 0.25.0

data.plot( x = 'Income'
          , y = 'Age'
          , kind = 'scatter'
          , figsize = (10, 10)
          , title = 'Pandas_Graphs'
          , grid = True
          , logx = False )

# %%
# loglog : bool or ‘sym’, default False
# Use log scaling or symlog scaling on both x and y axes. .. versionchanged:: 0.25.0

data.plot( x = 'Income'
          , y = 'Age'
          , kind = 'scatter'
          , figsize = (10, 10)
          , title = 'Pandas_Graphs'
          , grid = True
          , logx = True )

# %%
data.plot( x = 'Income'
          , y = 'Age'
          , kind = 'scatter'
          , figsize = (10, 10)
          , title = 'Pandas_Graphs'
          , grid = True
          , logx = True
          , logy = 'sym' )

# %%
data.plot( x = 'Income'
          , y = 'Age'
          , kind = 'scatter'
          , figsize = (10, 10)
          , title = 'Pandas_Graphs'
          , grid = True
          , logx = True
          , logy = None )

# %%
data.plot( x = 'Income'
          , y = 'Age'
          , kind = 'scatter'
          , figsize = (10, 10)
          , title = 'Pandas_Graphs'
          , grid = True
          , logx = True
          , logy = True )

# %%
data.plot( x = 'Income'
          , y = 'Age'
          , kind = 'scatter'
          , figsize = (10, 10)
          , title = 'Pandas_Graphs'
          , grid = True
          , logx = True
          , logy = 'sym'
          , loglog = 'sym' )

# %%
# fontsize : int, default None
# Font size for xticks and yticks.

data.plot( x = 'Income'
          , y = 'Age'
          , kind = 'scatter'
          , figsize = (10, 10)
          , title = 'Pandas_Graphs'
          , grid = True
          , fontsize = 20 )

# %%
# colorbar : bool, optional
# If True, plot colorbar (only relevant for ‘scatter’ and ‘hexbin’ plots).

data.plot( x = 'Income'
          , y = 'Age'
          , kind = 'scatter'
          , figsize = (10, 10)
          , title = 'Pandas_Graphs'
          , grid = True
          , fontsize = 20
          , colorbar = None )

# %%
data.plot( x = 'Income'
          , y = 'Age'
          , kind = 'scatter'
          , figsize = (10, 10)
          , title = 'Pandas_Graphs'
          , grid = True
          , fontsize = 20
          , colorbar = False )

# %%
data.plot( x = 'Income'
          , y = 'Age'
          , kind = 'scatter'
          , figsize = (10, 10)
          , title = 'Pandas_Graphs'
          , grid = True
          , fontsize = 20
          , colorbar = True )

# %%
data.plot( x = 'Income'
          , y = 'Age'
          , kind = 'hexbin'
          , figsize = (10, 10)
          , title = 'Pandas_Graphs'
          , grid = True
          , fontsize = 20
          , colorbar = True )
