# %%
import pandas as pd

# %%
data = pd.read_csv('Market_Basket_Optimisation.csv', header = None)    #We do header = None to make column as data.
data
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
data.shape
# Out:
# (7501, 20)

# %%
print( f"len( data.index ) = { len( data.index ) }" )
print( f"len( data.columns ) = { len( data.columns ) }" )
# Out:
# len( data.index ) = 7501
# len( data.columns ) = 20

# %%
data[1]
# Out:
# 0                 almonds
# 1               meatballs
# 2                     NaN
# 3                 avocado
# 4                    milk
#               ...
# 7496           light mayo
# 7497    frozen vegetables
# 7498                  NaN
# 7499            green tea
# 7500      frozen smoothie
# Name: 1, Length: 7501, dtype: object

# %%
data[1][56]
# Out:
# 'fresh tuna'

# %%
transactions = []

for i in range( len( data.index ) ):          #row 0 to 7500
    temp = []
    
    for j in range( len( data.columns ) ):   #For each row, all columns.
        temp.append( str(data[j][i]) )      #Appending [col][row] -> Select any row and then, append all col. data for that row.
    
    transactions.append( temp )

# %%
for i in transactions:
    print(i)
# Out:
# ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole weat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxydant juice', 'frozen smoothie', 'spinach', 'olive oil']
# ['burgers', 'meatballs', 'eggs', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# ['chutney', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# ['turkey', 'avocado', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# ...

# %%
len( transactions )
# Out:
# 7501

# %%
from apyori import apriori

# %%
5*7/7500       #Any product which is on sale 5 times per day. So, we are calculating the least total product sold in a week.

#So, Min_support = least total product sold/ Total no. of given days
# Out:
# 0.004666666666666667

# %%
ap = apriori( transactions, min_support = 0.004666666666666667, min_confidence = 0.2, min_lift = 3, min_length = 3 )

#Confidence is the desired accuracy rate. If 0.3 then, The prediction must be 30%
#min_lift must be 3 or more . min_lift = min_confidence/ min_support. Then, min_confidence should be high,
#min_length is minimum product threshold value -> how many product is max to max allowed in the apriori.

# %%
# ?ap

# %%
ap
# Out:
# <generator object apriori at 0x0000015CA8C42A48>

# %%
result = list(ap)
result
# Out:
# [RelationRecord(items=frozenset({'mushroom cream sauce', 'escalope'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)]),
#  RelationRecord(items=frozenset({'pasta', 'escalope'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)]),
#  RelationRecord(items=frozenset({'ground beef', 'herb & pepper'}), support=0.015997866951073192, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herb & pepper'}), items_add=frozenset({'ground beef'}), confidence=0.3234501347708895, lift=3.2919938411349285)]),
# ...

# %%
for i in result:
    print( f"i = {i} and len(i) = { len(i) }" )
    print()
# Out:
# i = RelationRecord(items=frozenset({'mushroom cream sauce', 'escalope'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)]) and len(i) = 3
#
# i = RelationRecord(items=frozenset({'pasta', 'escalope'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)]) and len(i) = 3
#
# i = RelationRecord(items=frozenset({'ground beef', 'herb & pepper'}), support=0.015997866951073192, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herb & pepper'}), items_add=frozenset({'ground beef'}), confidence=0.3234501347708895, lift=3.2919938411349285)]) and len(i) = 3
#
# ...

# %%
for i in result:
    for j in i:
        print( j, end = ' -> ' )
    
    print()
    print()
# Out:
# frozenset({'mushroom cream sauce', 'escalope'}) -> 0.005732568990801226 -> [OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)] ->
#
# frozenset({'pasta', 'escalope'}) -> 0.005865884548726837 -> [OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)] ->
#
# frozenset({'ground beef', 'herb & pepper'}) -> 0.015997866951073192 -> [OrderedStatistic(items_base=frozenset({'herb & pepper'}), items_add=frozenset({'ground beef'}), confidence=0.3234501347708895, lift=3.2919938411349285)] ->
#
# frozenset({'ground beef', 'tomato sauce'}) -> 0.005332622317024397 -> [OrderedStatistic(items_base=frozenset({'tomato sauce'}), items_add=frozenset({'ground beef'}), confidence=0.3773584905660377, lift=3.840659481324083)] ->
#
# ...

# %%
for i in result:
    print( i[2] )
    print()
# Out:
# [OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)]
#
# [OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)]
#
# [OrderedStatistic(items_base=frozenset({'herb & pepper'}), items_add=frozenset({'ground beef'}), confidence=0.3234501347708895, lift=3.2919938411349285)]
#
# [OrderedStatistic(items_base=frozenset({'tomato sauce'}), items_add=frozenset({'ground beef'}), confidence=0.3773584905660377, lift=3.840659481324083)]
#
# [OrderedStatistic(items_base=frozenset({'whole wheat pasta'}), items_add=frozenset({'olive oil'}), confidence=0.2714932126696833, lift=4.122410097642296)]
#
# [OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'shrimp'}), confidence=0.3220338983050847, lift=4.506672147735896)]
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
data[1].isnull().sum()
# Out:
# 1754

# %%
data[1] = data[1].fillna( 'nan', axis = 0 )

# %%
data[1].isnull().sum()
# Out:
# 0

# %%
plt.plot( data[0], data[1], linestyle = '--' )
plt.show()
